# %%
import pandas as pd
import numpy as np

import pickle
import json

# %%
# load model
with open('model.pkl', 'rb') as file_1:
    model_rf = pickle.load(file_1)

# %%
model_rf
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num_col', StandardScaler(),
#                                                   ['age', 'estimated_salary',
#                                                    'calls_made', 'sms_sent',
#                                                    'data_used', 'pincode',
#                                                    'num_dependents']),
#                                                  ('cat_col', OneHotEncoder(),
#                                                   ['telecom_partner', 'gender',
#                                                    'city']),
#                                                  ('hi_car', TargetEncoder(),
#                                                   ['state'])])),
#                 ('classifier', RandomForestClassifier())])

# %%
# Define the new data as a dictionary
new_data = {
    'customer_id': [8200], 
    'telecom_partner': ['Reliance Jio'],
    'gender': ['F'],
    'age': [30],
    'state': ['Karnataka'],
    'city': ['Kolkata'],
    'pincode': [755597],
    'date_of_registration': ['2020-01-01'],  
    'num_dependents': [2],
    'estimated_salary': [200000],
    'calls_made': [50],
    'sms_sent': [45],
    'data_used': [360]
}

# Create the DataFrame with a specified index (default index is fine here)
df_inf = pd.DataFrame(new_data)

# Display the DataFrame to verify
df_inf

#1	Reliance Jio	F	25	Karnataka	Kolkata	755597	2020-01-01	4	124962	44	45	-361
# Out:
#    customer_id telecom_partner gender  age      state     city  pincode  \
# 0         8200    Reliance Jio      F   30  Karnataka  Kolkata   755597
#
#   date_of_registration  num_dependents  estimated_salary  calls_made  \
# 0           2020-01-01               2            200000          50
#
#    sms_sent  data_used
# 0        45        360

# %%
predict = model_rf.predict(df_inf)

# %%
predict
# Out:
# array([False])
